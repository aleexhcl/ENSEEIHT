# %% [markdown]
# # Intégration numérique avec Julia, une introduction

# %% [markdown]
# ## Introduction
# Pour la documentation voire
# [Documentation of DifferentialEquations.jl](https://diffeq.sciml.ai/stable/)
#
#
# Il nous faut tout d'abord importer les bons packages de Julia

# %%
# import Pkg; Pkg.add("DifferentialEquations")
# Pkg.add("Plots")
using DifferentialEquations
using Plots
# Out:
#     Updating registry at `~/.julia/registries/General`
#    Resolving package versions...
#    Installed FunctionWrappers ───────────────── v1.1.2
#    Installed ExponentialUtilities ───────────── v1.13.0
#    Installed DifferentialEquations ──────────── v7.1.0
#    Installed Random123 ──────────────────────── v1.5.0
#    Installed SIMDDualNumbers ────────────────── v0.1.0
#    Installed CPUSummary ─────────────────────── v0.1.19
#    Installed LoopVectorization ──────────────── v0.12.108
#    Installed Optim ──────────────────────────── v1.6.2
#    Installed PositiveFactorizations ─────────── v0.2.4
#    Installed Distances ──────────────────────── v0.10.7
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed Sundials_jll ───────────────────── v5.2.0+1
#    Installed TriangularSolve ────────────────── v0.1.11
#    Installed LineSearches ───────────────────── v7.1.1
#    Installed BandedMatrices ─────────────────── v0.16.13
#    Installed IterativeSolvers ───────────────── v0.9.2
#    Installed Hwloc_jll ──────────────────────── v2.7.1+0
#    Installed CpuId ──────────────────────────── v0.3.0
#    Installed StrideArraysCore ───────────────── v0.3.2
#    Installed ArrayLayouts ───────────────────── v0.8.5
#    Installed Static ─────────────────────────── v0.6.0
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed NonlinearSolve ─────────────────── v0.3.16
#    Installed LinearSolve ────────────────────── v1.15.0
#    Installed TreeViews ──────────────────────── v0.3.0
#    Installed ZygoteRules ────────────────────── v0.2.2
#    Installed DiffEqNoiseProcess ─────────────── v5.9.0
#    Installed NLSolversBase ──────────────────── v7.8.2
#    Installed Polyester ──────────────────────── v0.6.8
#    Installed ConstructionBase ───────────────── v1.3.0
#    Installed DiffEqJump ─────────────────────── v8.3.0
#    Installed StochasticDiffEq ───────────────── v6.46.0
#    Installed PoissonRandom ──────────────────── v0.4.0
#    Installed Hwloc ──────────────────────────── v2.0.0
#    Installed VertexSafeGraphs ───────────────── v0.2.0
#    Installed DiffEqCallbacks ────────────────── v2.22.0
#    Installed NLsolve ────────────────────────── v4.5.1
#    Installed HostCPUFeatures ────────────────── v0.1.7
#    Installed Setfield ───────────────────────── v0.8.2
#    Installed KrylovKit ──────────────────────── v0.5.4
#    Installed libblastrampoline_jll ──────────── v3.1.0+2
#    Installed CommonSolve ────────────────────── v0.2.0
#    Installed DEDataArrays ───────────────────── v0.2.2
#    Installed LayoutPointers ─────────────────── v0.1.6
#    Installed SparseDiffTools ────────────────── v1.21.0
#    Installed Sundials ───────────────────────── v4.9.3
#    Installed LevyArea ───────────────────────── v1.0.0
#    Installed VectorizationBase ──────────────── v0.21.29
#    Installed FastClosures ───────────────────── v0.3.2
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.3
#    Installed PreallocationTools ─────────────── v0.2.4
#    Installed RecursiveArrayTools ────────────── v2.26.3
#    Installed FiniteDiff ─────────────────────── v2.11.0
#    Installed ArrayInterface ─────────────────── v5.0.7
#    Installed ResettableStacks ───────────────── v1.1.1
#    Installed BoundaryValueDiffEq ────────────── v2.7.1
#    Installed SteadyStateDiffEq ──────────────── v1.6.6
#    Installed RecursiveFactorization ─────────── v0.2.10
#    Installed KLU ────────────────────────────── v0.3.0
#    Installed DiffEqBase ─────────────────────── v6.83.1
#    Installed RandomNumbers ──────────────────── v1.5.3
#    Installed OrdinaryDiffEq ─────────────────── v6.9.0
#    Installed PolyesterWeave ─────────────────── v0.1.5
#    Installed MuladdMacro ────────────────────── v0.2.2
#    Installed CEnum ──────────────────────────── v0.4.1
#    Installed SLEEFPirates ───────────────────── v0.6.32
#    Installed ThreadingUtilities ─────────────── v0.5.0
#    Installed DelayDiffEq ────────────────────── v5.35.1
#    Installed SciMLBase ──────────────────────── v1.29.0
#    Installed Krylov ─────────────────────────── v0.8.0
#    Installed FastBroadcast ──────────────────── v0.1.15
#    Installed CloseOpenIntervals ─────────────── v0.1.6
#    Installed LabelledArrays ─────────────────── v1.8.0
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [0c46a032] + DifferentialEquations v7.1.0
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [4fba245c] + ArrayInterface v5.0.7
#   [4c555306] + ArrayLayouts v0.8.5
#   [aae01518] + BandedMatrices v0.16.13
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.3
#   [764a87c0] + BoundaryValueDiffEq v2.7.1
#   [fa961155] + CEnum v0.4.1
#   [2a0fbf3d] + CPUSummary v0.1.19
#   [fb6a15b2] + CloseOpenIntervals v0.1.6
#   [38540f10] + CommonSolve v0.2.0
#   [187b0558] + ConstructionBase v1.3.0
#   [adafc99b] + CpuId v0.3.0
#   [754358af] + DEDataArrays v0.2.2
#   [bcd4f6db] + DelayDiffEq v5.35.1
#   [2b5f629d] + DiffEqBase v6.83.1
#   [459566f4] + DiffEqCallbacks v2.22.0
#   [c894b116] + DiffEqJump v8.3.0
#   [77a26b50] + DiffEqNoiseProcess v5.9.0
#   [0c46a032] + DifferentialEquations v7.1.0
#   [b4f34e82] + Distances v0.10.7
#   [d4d017d3] + ExponentialUtilities v1.13.0
#   [7034ab61] + FastBroadcast v0.1.15
#   [9aa1b823] + FastClosures v0.3.2
#   [6a86dc24] + FiniteDiff v2.11.0
#   [069b7b12] + FunctionWrappers v1.1.2
#   [3e5b6fbb] + HostCPUFeatures v0.1.7
#   [0e44f5e4] + Hwloc v2.0.0
#   [615f187c] + IfElse v0.1.1
#   [42fd0dbc] + IterativeSolvers v0.9.2
#   [ef3ab10e] + KLU v0.3.0
#   [ba0b0d4f] + Krylov v0.8.0
#   [0b1a1467] + KrylovKit v0.5.4
#   [2ee39098] + LabelledArrays v1.8.0
#   [10f19ff3] + LayoutPointers v0.1.6
#   [2d8b4e74] + LevyArea v1.0.0
#   [d3d80556] + LineSearches v7.1.1
#   [7ed4a6bd] + LinearSolve v1.15.0
#   [bdcacae8] + LoopVectorization v0.12.108
#   [d125e4d3] + ManualMemory v0.1.8
#   [46d2c3a1] + MuladdMacro v0.2.2
#   [d41bc354] + NLSolversBase v7.8.2
#   [2774e3e8] + NLsolve v4.5.1
#   [8913a72c] + NonlinearSolve v0.3.16
#   [429524aa] + Optim v1.6.2
#   [1dea7af3] + OrdinaryDiffEq v6.9.0
#   [e409e4f3] + PoissonRandom v0.4.0
#   [f517fe37] + Polyester v0.6.8
#   [1d0040c9] + PolyesterWeave v0.1.5
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [d236fae5] + PreallocationTools v0.2.4
#   [74087812] + Random123 v1.5.0
#   [e6cf234a] + RandomNumbers v1.5.3
#   [731186ca] + RecursiveArrayTools v2.26.3
#   [f2c3362d] + RecursiveFactorization v0.2.10
#   [ae5879a3] + ResettableStacks v1.1.1
#   [3cdde19b] + SIMDDualNumbers v0.1.0
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.32
#   [0bca4576] + SciMLBase v1.29.0
#   [efcf1570] + Setfield v0.8.2
#   [47a9eef4] + SparseDiffTools v1.21.0
#   [aedffcd0] + Static v0.6.0
#   [9672c7b4] + SteadyStateDiffEq v1.6.6
#   [789caeaf] + StochasticDiffEq v6.46.0
#   [7792a7ef] + StrideArraysCore v0.3.2
#   [c3572dad] + Sundials v4.9.3
#   [8290d209] + ThreadingUtilities v0.5.0
#   [a2a6695c] + TreeViews v0.3.0
#   [d5829a12] + TriangularSolve v0.1.11
#   [3d5dd08c] + VectorizationBase v0.21.29
#   [19fa3120] + VertexSafeGraphs v0.2.0
#   [700de1a5] + ZygoteRules v0.2.2
#   [e33a78d0] + Hwloc_jll v2.7.1+0
#   [fb77eaff] + Sundials_jll v5.2.0+1
#   [8e850b90] + libblastrampoline_jll v3.1.0+2
#   [9fa8497b] + Future
#   [4536629a] + OpenBLAS_jll
#   [bea87d4a] + SuiteSparse_jll
# Precompiling project...
#   ✓ CEnum
#   ✓ MuladdMacro
#   ✓ ConstructionBase
#   ✓ PositiveFactorizations
#   ✓ ManualMemory
#   ✓ FunctionWrappers
#   ✓ PoissonRandom
#   ✓ SIMDTypes
#   ✓ IfElse
#   ✓ TreeViews
#   ✓ CpuId
#   ✓ FastClosures
#   ✓ Distances
#   ✓ CommonSolve
#   ✓ ZygoteRules
#   ✓ RandomNumbers
#   ✓ KrylovKit
#   ✓ Hwloc_jll
#   ✓ IterativeSolvers
#   ✓ OpenBLAS_jll
#   ✓ LevyArea
#   ✓ libblastrampoline_jll
#   ✓ Krylov
#   ✓ ThreadingUtilities
#   ✓ ResettableStacks
#   ✓ SuiteSparse_jll
#   ✓ Static
#   ✓ Setfield
#   ✓ Hwloc
#   ✓ VertexSafeGraphs
#   ✓ BitTwiddlingConvenienceFunctions
#   ✓ Random123
#   ✓ CPUSummary
#   ✓ KLU
#   ✓ HostCPUFeatures
#   ✓ PolyesterWeave
#   ✓ ArrayLayouts
#   ✓ Sundials_jll
#   ✓ ArrayInterface
#   ✓ CloseOpenIntervals
#   ✓ LayoutPointers
#   ✓ ExponentialUtilities
#   ✓ StrideArraysCore
#   ✓ FiniteDiff
#   ✓ LabelledArrays
#   ✓ Polyester
#   ✓ FastBroadcast
#   ✓ BandedMatrices
#   ✓ RecursiveArrayTools
#   ✓ PreallocationTools
#   ✓ NLSolversBase
#   ✓ SparseDiffTools
#   ✓ LineSearches
#   ✓ NLsolve
#   ✓ SciMLBase
#   ✓ Optim
#   ✓ DEDataArrays
#   ✓ VectorizationBase
#   ✓ SLEEFPirates
#   ✓ SIMDDualNumbers
#   ✓ LoopVectorization
#   ✓ TriangularSolve
#   ✓ RecursiveFactorization
#   ✓ LinearSolve
#   ✓ NonlinearSolve
#   ✓ DiffEqBase
#   ✓ DiffEqNoiseProcess
#   ✓ DiffEqJump
#   ✓ BoundaryValueDiffEq
#   ✓ Sundials
#   ✓ OrdinaryDiffEq
#   ✓ DiffEqCallbacks
#   ✓ DelayDiffEq
#   ✓ StochasticDiffEq
#   ✓ SteadyStateDiffEq
#   ✓ DifferentialEquations
#   76 dependencies successfully precompiled in 226 seconds (176 already precompiled)
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.6/Project.toml`
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`

# %% [markdown]
# ## Exemple 1
#
# Nous allons ici résoudre le problème à valeur initiale
# $$(IVP)\left\{\begin{array}{l}
# \dot{x}_1(t)=x_1(t)+x_2(t)+\sin t\\
# \dot{x}_2(t)=-x_1(t)+3x_2(t)\\
# x_1(0)=-9/25\\
# x_2(0)=-4/25,
# \end{array}\right.
# $$
#
# - Ecrire la fonction $f$ qui permet d'écrire l'équation différentielle sous la forme $\dot{x}(t)=f(t,x(t))$
# - Vérifier que la solution de $(IVP$ est
# $$\begin{align*}
# x_1(t)&= (-1/25)(13\sin t+9\cos t)\\
# x_2(t)&= (-1/25)(3\sin t+4\cos t).
# \end{align*}$$
# - Coder la fonction $f$

# %%
function exemple1(x,p,t)
# second member of the IVP
# x : state
# p : paramter vector
# t : time, variable not use here
    xpoint = zeros(size(x))

    xpoint[1] = x[1] + x[2] + sin(t)
    xpoint[2] = -x[1] + 3*x[2]
    
    return xpoint
end
p = []
t0 = 0.; tf = 10
tspan = (t0,tf)
x0 = [-9/25 -4/25]
prob = ODEProblem(exemple1,x0,tspan,p)          # défini le problème en Julia
sol = solve(prob)
p1 = plot(sol, label = ["x_1(t)" "x_2(t)"], title = "default options", lw = 0.5) # lw = linewidth

# %% [markdown]
# ## Le contrôle du pas
# Les bons intégrateurs numériques ont une mise à jour automatique du pas. Pour les méthodes de Runge-Kutta par exemple, sur un pas $[t_0, t_{1}]$ on calcule par 2 schémas différents deux solutions approchées à l'instant $t_{1}~: x_{1}$ et $\hat{x}_{1}$ dont l'erreur local est respectivement en $O(h^p)$ et $O(h^{p+1})$ (les err
# eurs globales sont elles en $O(h^{p-1})$ et $O(h^p)$). Ainsi on peut estimer l'erreur locale du schéma le moins précis à l'aide de la différence $x_{1}-\hat{x}_{1}$. On peut alors estimer le pas de façon à avoir la norme de cette différence inférieur à une tolérance donnée $Tol$ ou encore à avoir
# $$\frac{\|x_{1}-\hat{x}_{1}\|}{Tol}<1.$$
#
# En pratique on considère des tolérences absolue et relative composante par composante et on définit : $sc_i = Atol_i + \max(|x_{0i}|,|x_{1i}|)Rtol_i$. On calcule alors le pas de façon à avoir
#
# $$err = \sqrt{\frac{1}{n}\sum_{i=1}^n\left(\frac{x_{1i}-\hat{x}_{1i}}{sc_i}\right)^2}<1.$$
#
#
# Référence : [Hairer, Nørsett, Wanner (2008) Solving Ordinary Differential Equations I Nonstiff Problems DOI: 10.1007/978-3-540-78862-1](https://link.springer.com/book/10.1007/978-3-540-78862-1)
#
# Dans `Julia`, on peut modifier les valeurs par défaut  : reltol = 1.e-3 et abstol = 1.e-6
# (lorsque ces valeurs sont des scalaires, on considère les mêmes quantités pour toutes les composantes).
#
# Réaliser l'intégration numérique pour
# - reltol = 1.e-3 et abstol = 1.e-6
# - reltol = 1.e-6 et abstol = 1.e-9
# - reltol = 1.e-10 et abstol = 1.e-15
#
# et afficher les résultats en ajoutant la solution.

# %% [markdown]
# ## Commentaires?

# %%
sol = solve(prob, reltol = 1.e-3, abstol = 1.e-6)
p1 = plot(sol, label = ["x1(t)" "x2(t)"], title = "reltol=1e-3, abstol=1e-6", lw = 0.5) # lw = linewidth
# sol 1 reltol et abs trop faible pour afficher bon res 
# TO COMPLETE
sol = solve(prob, reltol = 1.e-6, abstol = 1.e-9)
p2 = plot(sol, label = ["x1(t)" "x2(t)"], title = "reltol=1e-6, abstol=1e-9", lw = 0.5)

sol = solve(prob, reltol = 1.e-10, abstol = 1.e-15)
p3 = plot(sol, label = ["x1(t)" "x2(t)"], title = "reltol=1e-10, abstol=1e-15", lw = 0.5)

#
T = t0:(tf-t0)/100:tf
sinT = sin.(T)                                # opération vectorielle
cosT = cos.(T)
p4 = plot(T,[(-1/25)*(13*sinT+9*cosT) (-1/25)*(3*sinT+4*cosT)], label = ["x_1(t)" "x_2(t)"], title = "Solution exacte")
plot(p1,p2,p3,p4, size=(900, 600))

# %% [markdown]
# ## Pendule simple
# ### Introduction
# On s'intéresse ici au pendule simple. Les principes physiques de la mécanique classique donnent comme équation qui régit l'évolution du mouvement
#
# $$ ml^2\ddot{\alpha}(t)+mlg\sin(\alpha(t)) +k\dot{\alpha}(t)=0,$$
# où $\ddot{\alpha}(t)$ désigne la dérivée seconde de l'angle $\alpha$ par rapport au temps $t$.
#
# - En prenant comme variable d'état qui décrit le système $x(t)=(x_1(t),x_2(t))=(\alpha(t), \dot{\alpha}(t))$, écrire la fonction $f$ qui permet d'écrire l'équation différentielle sous la forme $\dot{x}(t) = f(t,x(t))$
# - Coder cette fonction

# %%
function pendule(x,p,t)
# second member of the IVP
# x : state
# p : paramter vector
# t : time, variable not use here
    xpoint = zeros(size(x))

# TO COMPLETE
    xpoint[1] = x[2]
    xpoint[2] = - (p[3]/(p[2]^2))*x[2] - (p[1]/p[2])*sin(x[1])
    
    return xpoint  
end;

# %%
# Main
#
g = 9.81; l = 10; k = 0.;
p = [g,l,k]      # constantes
theta0 = pi/3
t0 = 0.
tf = 3*pi*sqrt(l/g)*(1 + theta0^2/16 + theta0^4/3072) # 2*approximation of the period
tspan = (t0,tf)                             # instant initiel et terminal
x0 = [theta0,0]                             # état initial
prob = ODEProblem(pendule,x0,tspan,p)       # défini le problème en Julia
sol = solve(prob, reltol = 1.e-6, abstol = 1.e-9)                           # réalise l'intégration numérique
plot(sol, label = ["x1(t)" "x2(t)"], lw = 0.5)

# %% [markdown]
# ## Diagrammes de phases

# %%
# Main
#
g = 9.81; l = 1.5; k = 0.15;
p = [g l k]
plot()
for theta0 in 0:(2*pi)/10:2*pi
    theta0_princ = theta0
    tf = 3*pi*sqrt(l/g)*(1 + theta0_princ^2/16 + theta0_princ^4/3072) # 2*approximation of the period
    tspan = (0.0,tf)
    x0 = [theta0 0]
    prob = ODEProblem(pendule,x0,tspan,p)
    sol = solve(prob)
    plot!(sol,vars=(1,2), xlabel = "x1", ylabel = "x2", legend = false, lw = 0.5)  # lw = linewidth
end
theta0 = pi-10*eps()
x0 = [theta0 0]
tf = 70                              # problem for tf=50 1/4 of the period!
tspan = (0.0,tf)
prob = ODEProblem(pendule,x0,tspan,p)
sol = solve(prob)
plot!(sol,vars=(1,2), xlims = (-2*pi,4*pi), xlabel = "x1", ylabel = "x2", legend = false, lw = 0.5)  # lw = linewidth

theta0 = pi+10*eps()
x0 = [theta0 0]
tf = 70
tspan = (0.0,tf)
prob = ODEProblem(pendule,x0,tspan,p)
sol = solve(prob)
plot!(sol,vars=(1,2), xlims = (-2*pi,4*pi), xlabel = "x1", ylabel = "x2", legend = false, lw = 0.5)  # lw = linewidth

# circulation case
for thetapoint0 in 0:0.2:2         
    tf = 10
    tspan = (0.,tf)
    x0 = [-pi thetapoint0]                # thetapoint0 > 0 so theta increases from -pi to ...
    prob = ODEProblem(pendule,x0,tspan,p)
    sol = solve(prob)
    plot!(sol,vars=(1,2), xlabel = "x1", ylabel = "x2", legend = false, lw = 0.5)  # lw = linewidth
end
for thetapoint0 in -2:0.2:0
    tf = 10
    tspan = (0.,tf)
    x0 = [3*pi thetapoint0]              # thetapoint0 < 0 so theta decreases from 3pi to ...
    prob = ODEProblem(pendule,x0,tspan,p)
    sol = solve(prob)
    plot!(sol,vars=(1,2), xlabel = "x1", ylabel = "x2", legend = false, lw = 0.5)  # lw = linewidth
end
plot!([-pi 0 pi 2*pi 3*pi], [0 0 0 0 0], seriestype=:scatter)
plot!(xlims = (-pi,3*pi))

# %%
# Main
#
g = 9.81; l = 1.5; k = 0.15;
p = [g l k]
plot()
for theta0 in 0:(2*pi)/2:2*pi
    theta0_princ = theta0
    tf = 3*pi*sqrt(l/g)*(1 + theta0_princ^2/16 + theta0_princ^4/3072) # 2*approximation of the period
    tspan = (0.0,tf)
    x0 = [theta0 0]
    prob = ODEProblem(pendule,x0,tspan,p)
    sol = solve(prob)
    plot!(sol,vars=(1,2), xlabel = "x1", ylabel = "x2", legend = false, lw = 0.5)  # lw = linewidth
end
theta0 = pi-10*eps()
x0 = [theta0 0]
tf = 50                              # problem for tf=50 1/4 of the period!
tspan = (0.0,tf)
prob = ODEProblem(pendule,x0,tspan,p)
sol = solve(prob)
plot!(sol,vars=(1,2), xlims = (-2*pi,4*pi), xlabel = "x1", ylabel = "x2", legend = false, lw = 0.5)  # lw = linewidth

theta0 = pi+10*eps()
x0 = [theta0 0]
tf = 50
tspan = (0.0,tf)
prob = ODEProblem(pendule,x0,tspan,p)
sol = solve(prob)
plot!(sol,vars=(1,2), xlims = (-2*pi,4*pi), xlabel = "x1", ylabel = "x2", legend = false, lw = 0.5)  # lw = linewidth

# circulation case
for thetapoint0 in 0:0.5:2         
    tf = 10
    tspan = (0.,tf)
    x0 = [-pi thetapoint0]                # thetapoint0 > 0 so theta increases from -pi to ...
    prob = ODEProblem(pendule,x0,tspan,p)
    sol = solve(prob)
    plot!(sol,vars=(1,2), xlabel = "x1", ylabel = "x2", legend = false, lw = 0.5)  # lw = linewidth
end
for thetapoint0 in -2:0.5:0
    tf = 10
    tspan = (0.,tf)
    x0 = [3*pi thetapoint0]              # thetapoint0 < 0 so theta decreases from 3pi to ...
    prob = ODEProblem(pendule,x0,tspan,p)
    sol = solve(prob)
    plot!(sol,vars=(1,2), xlabel = "x1", ylabel = "x2", legend = false, lw = 0.5)  # lw = linewidth
end
plot!([-pi 0 pi 2*pi 3*pi], [0 0 0 0 0], seriestype=:scatter)
plot!(xlims = (-pi,3*pi), size=(900, 600))

# %% [markdown]
# - Interprétez ces graphiques
# - On considère le cas où $k=0.15$ (on introduit un frotement). Que se passe-t-til?

# %% [markdown]
# ## Modèle de Van der Pol
# ### Exemple de cycle limite
# L'équation différentielle considérée est l'équation de Van der Pol
# $$(IVP)\left\{\begin{array}{l}
# \dot{y}_1(t)=y_2(t)\\
# \dot{y}_2(t)=(1-y_1^2(t))y_2(t)-y_1(t)\\
# y_1(0)=2.00861986087484313650940188\\
# y_2(0)=0
# \end{array}\right.
# $$
# $t_f=T=6.6632868593231301896996820305$
#
#
# La solution de ce problème de Cauchy est périodique de période $T$.
#
# Résoudre et de visualiser la solution pour les points de départ :
# - x0 = [2.00861986087484313650940188,0]
# - [x01 , 0] pour x01 dans -2:0.4:0
# - [0 , x02] pour x02 dans 2:1:4

# %%
function vdp(x,p,t)
# Van der Pol model
# second member of the IVP
# x : state
#     real(2)
# p : parameter vector
# t : time, variable not use here
#     real
# Output
# xpoint : vector of velocity
#          same as x

    xpoint = zeros(size(x))

# TO COMPLETE
    
    xpoint[1] = x[2]
    xpoint[2] = (1-x[1]^2)*x[2] - x[1]
    
    return xpoint
end;

# %%
# Main
#
tf = 6.6632868593231301896996820305
tspan = (0.0, tf)
x0 = [2.00861986087484313650940188,0]
mu = 1
p = [mu]
t0 = 0.;
tspan = (t0,tf)
println("x0 = $x0, p = $p, tspan = $tspan")
prob = ODEProblem(vdp,x0,tspan,p)
sol = solve(prob)
plot(sol,vars=(1,2), xlabel = "x_1", ylabel = "x_2", legend = false)
for x01 in -2:0.4:0 #4.5:4.5
    x0 = [x01,0]
    prob = ODEProblem(vdp,x0,tspan,p)
    sol = solve(prob)#,force_dtmin=true)# 
    plot!(sol,vars=(1,2), xlabel = "x_1", ylabel = "x_2", legend = false) 
end
for x02 in 2:1:4
    x0 = [0.,x02]
    prob = ODEProblem(vdp,x0,tspan,p)
    sol = solve(prob)#solve(prob,Tsit5(),reltol=1e-8,abstol=1e-8)
    plot!(sol,vars=(1,2), xlabel = "x_1", ylabel = "x_2", legend = false)
end
plot!([0], [0], seriestype=:scatter)        # point visualisation
plot!(xlims = (-2.5,5))
# Out:
# x0 = [2.0086198608748433, 0.0], p = [1], tspan = (0.0, 6.66328685932313)

# %% [markdown]
# ## Flots en dimension 2
#
# ### Flot des extrémales pour le problème de conrôle optimal
#
# On considère le problème de contrôle optimal suivant:
#
# $$ \frac{1}{2}\int_0^{1} u^2(t)\,\mathrm{d}t \to \min, $$
#
# où
#
# $$ \dot{x}(t) = -x(t) + u(t)$$
#
# $$ x(0)=x_0=-1,\quad x(1)=0. $$
#
# Le but est ici de tracer les extrémales et le flot associé pour des points initiaux $z(0) = (x_0, p(0))$.

# %%
function plot_traj(plt,f,Z0,tf; par=[])
    """ 
    Plot the trajectories in the phase plan of the ode dot{x}(t)=f(t,z(t))
    The initial points are in the matrix `Z0`
    -------
    
    parameters (input)
    ------------------
    plt : plot object
    f  : function f(x,p,t)
    Z0 : array of float(n,nbpoints)
         Z0[:,i] = initial point number i
    returns
    -------
    nothing
    """
    nbpoints = size(Z0,2)
    tspan = (0. , tf)
    for i in 1:nbpoints                      
        prob = ODEProblem(f,Z0[:,i],tspan,par)          # défini le problème en Julia
        sol = solve(prob)
        plot!(plt, sol, vars = (1,2),legend = false, color = :blue) # lw = linewidth
     end
    return nothing
end
# Out:
# plot_traj (generic function with 1 method)

# %%
function plot_flow(plt,f,Z0,tf; par=[])
    """ 
    plot the flows of the ode dot{x}(t)=f(t,z(t))
    The initial points are in the matrix `Z0`
    -------
    
    parameters (input)
    ------------------
    plt : plot object
    f  : function f(x,p,t)
    Z0 : array of float(n,nbpoints)
         Z0[:,i] = initial point number i
    returns
    -------
    nothing
    """
    nbpoints = size(Z0,2)
    tspan = (0. , tf)
    T = range(0.,tf,length=4)
    for i in 1:nbpoints        
        # TO COMPLETE
        prob = ODEProblem(f,Z0[:,i],tspan,par)          # défini le problème en Julia
        sol = solve(prob)
        for t in T
            plot!(plt, [sol(t)[1]], [sol(t)[2]], seriestype=:scatter,legend = false, color = :red, markersize=1) # lw = linewidth
        end
    end
    return nothing
end;

# %% [markdown]
# - Compléter la fonction suivante pour tracer le flot pour 4 valeurs de $t$
#
# Remarque : `sol(t)` donne la valeur de l'approximation de la solution à l'instant $t$

# %%
function fun1(z,p,t)
    zpoint = similar(z)
    zpoint[1] = -z[1] + z[2]
    zpoint[2] = z[2]
    return zpoint
end

t0 = 0; tf = 1.;

seg = range(-1.,1.,length=10)
Z0 = transpose([-ones(size(seg)) seg])
plt1 = plot()
plot_traj(plt1,fun1,Z0,tf)

seg = range(-1.,1.,length=200)
Z0 = transpose([-ones(size(seg)) seg])
plot_flow(plt1,fun1,Z0,tf)
plot!(plt1, xlims = (-2.,1))
plot!(plt1,[0.,0.],[-3.,3], linestyle = :dot, color = :black)

# %% [markdown]
# - Retrouvez graphiquement la solution du problème de contrôle optimal
# - La droite de départ se transforme par le plot en une droite, pourquoi?

# %% [markdown]
# ### Flot des extrémales pour le problème de conrôle optimal
#
# On considère le problème de contrôle optimal suivant:
#
# $$ \frac{1}{2}\int_0^{1} u^2(t)\,\mathrm{d}t \to \min, $$
#
# où
#
# $$ \dot{x}(t) = -x(t) + \alpha x^2(t) + u(t)$$
#
# $$ x(0)=x_0=-1,\quad x(1)=0. $$
#
# Le but est ici de tracer les extrémales et le flot associé pour des points initiaux $z(0) = (x_0, p(0))$.

# %%
function fun2(z,p,t)
    α = p
    zpoint = similar(z)
    zpoint[1] = -z[1] + α*z[1]^2 + z[2]
    zpoint[2] = (1. - 2*α*z[1])*z[2]
    return zpoint
end

t0 = 0; tf = 1.;
α = 1.5
seg = range(-0.,2,length=10)
Z0 = transpose([-ones(size(seg)) seg])
plt1 = plot()
plot_traj(plt1,fun2,Z0,tf,par=α)

seg = range(-0.,2,length=200)
Z0 = transpose([-ones(size(seg)) seg])
plot_flow(plt1,fun2,Z0,tf,par=α)
#plot!(plt1, xlims = (-2.,1))
plot!(plt1,[0.,0.],[0.,4], linestyle = :dot, color = :black)
plot(plt1)
